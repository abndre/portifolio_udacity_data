# %% [markdown]
# # Stack Overflow Data - 2017 Survey

# %% [markdown]
# ## Imports necessary for first analisys
# ### gather

# %%
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = None
# %config IPCompleter.greedy=True

# %%
df = pd.read_csv('survey_results_public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
df.shape
# Out:
# (51392, 154)

# %% [markdown]
# ## Question
#
# 1.The most frequent languages with professionals want to know
#
# 2.Average salary for happynes
#
# 3.Which programming language has the highest job satisfaction
#
# ## Analysis
#
# This dataframe have mane columns, but for out analyis we use only 5

# %% [markdown]
# ## First analysis
#
# ### Next language based in WantWorkLanguage
#
# 1.The most frequent languages with professionals want to know

# %%
def top_5_next_language(df_colum):
    """This function split the colum and count values"""
    temp_list = []
    next_languge = df_colum.dropna()
    for row in next_languge.to_list():
        temp_value = row.split(";")
        temp_value = [x.strip(' ') for x in temp_value]
        temp_list = temp_list + temp_value
    
    df_temp = pd.DataFrame(temp_list, columns=['language'])
    print(df_temp.language.value_counts().head())
    df_temp.language.value_counts().sort_values().plot(kind = 'barh')
    return df_temp
    


top_5_next_language(df.WantWorkLanguage);
# Out:
# JavaScript    16327
# Python        12570
# SQL           11217
# C#            10187
# Java           9988
# Name: language, dtype: int64

# %% [markdown]
# # Second analysis
